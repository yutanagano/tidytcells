# %% [markdown]
# # Catalogueing human MHC gene reference data

# %%
import sys
import os
sys.path.append('/home/yutanagano/Projects/graph-gang-databases/')
os.chdir('/home/yutanagano/Projects/graph-gang-databases/')

# %%
import json
import pandas as pd
import re
from xml.etree import ElementTree as ET

# %% [markdown]
# ## Catalogueing alternate/deprecated names for HLA genes

# %%
hgnc = pd.read_csv('/home/yutanagano/UCLOneDrive/graph-gang-databases/data/hgnc/hgnc.tsv', sep='\t')

# %%
mhc_genes = hgnc[hgnc['Gene group name'].notna()]
mhc_genes = mhc_genes[mhc_genes['Gene group name'].str.contains('Histocompatibility complex')]

# %%
mhc_genes_with_aliases = mhc_genes[mhc_genes['Alias symbols'].notna()][['Approved symbol', 'Alias symbols']]
mhc_genes_with_aliases['Alias symbols'] = mhc_genes_with_aliases['Alias symbols'].map(lambda x: x.split(', '))
mhc_genes_with_aliases.columns = ['Approved symbol', 'Synonym']
mhc_genes_with_aliases = mhc_genes_with_aliases.explode('Synonym')

# %%
mhc_genes_with_depnames = mhc_genes[mhc_genes['Previous symbols'].notna()][['Approved symbol', 'Previous symbols']]
mhc_genes_with_depnames['Previous symbols'] = mhc_genes_with_depnames['Previous symbols'].map(lambda x: x.split(', '))
mhc_genes_with_depnames.columns = ['Approved symbol', 'Synonym']
mhc_genes_with_depnames = mhc_genes_with_depnames.explode('Synonym')

# %%
mhc_synonyms = pd.concat([mhc_genes_with_aliases, mhc_genes_with_depnames])
mhc_synonyms = mhc_synonyms.applymap(lambda symbol: symbol.replace('HLA-', ''))
mhc_synonyms = mhc_synonyms.groupby('Synonym').aggregate(lambda x: x.tolist())

# %%
# Discard ambiguous synonyms
mhc_synonyms = mhc_synonyms[mhc_synonyms['Approved symbol'].map(len) == 1].copy()
mhc_synonyms['Approved symbol'] = mhc_synonyms['Approved symbol'].map(lambda x: x.pop())

# %%
# Discard redundant items (synonym == approved symbol)
mhc_synonyms = mhc_synonyms[mhc_synonyms.index != mhc_synonyms['Approved symbol']]

# %%
mhc_synonyms['Approved symbol'].to_json('src/resources/human_mhc_synonyms.json', indent=4)

# %% [markdown]
# ## Catalogueing all known MHC proteins, G groups and P groups

# %%
hla_alleles = pd.read_csv(
    '/home/yutanagano/UCLOneDrive/graph-gang-databases/data/hnc_imgt/imgt_hla_allele_list.csv',
    skiprows=6
)

# %%
gp_xml = ET.parse('/home/yutanagano/UCLOneDrive/graph-gang-databases/data/hnc_imgt/hla.xml')
alleles_xml = gp_xml.getroot()

# %%
# Get all G groups
g_groups = list(dict.fromkeys(sorted([
    g_group.attrib['status'] for g_group in
    alleles_xml.iter('{http://hla.alleles.org/xml}hla_g_group')
    if g_group.attrib['status'] != 'None'
])))

# %%
# Get all P groups
p_groups = list(dict.fromkeys(sorted([
    p_group.attrib['status'] for p_group in
    alleles_xml.iter('{http://hla.alleles.org/xml}hla_p_group')
    if p_group.attrib['status'] != 'None'
])))

# %%
def decompose_hla(gene_str: str, max_spec_field_depth: int = 2):
    m = re.match(r'^([A-Z]|D[M-R][AB]\d?)\*([\dGP:]+)[LSCAQN]?$', gene_str)

    if m is None:
        # exclude all strictly non-HLA gene allele data (e.g. HFE, MICA/B)
        print(f'Ignoring {gene_str}...')
        return None
    
    gene = m.group(1)
    spec_fields = m.group(2).split(':')[:max_spec_field_depth]
    
    return (gene,) + tuple(spec_fields)

# %%
g_groups_decomposed = [decompose_hla(g_group, 4) for g_group in g_groups if decompose_hla(g_group, 4) is not None]
p_groups_decomposed = [decompose_hla(p_group, 4) for p_group in p_groups if decompose_hla(p_group, 4) is not None]
proteins_decomposed = [
    decompose_hla(allele) for allele in hla_alleles['Allele']
    if not 'N' in allele and decompose_hla(allele) is not None
]
# Out:
# Ignoring HFE*001:01:01...
# Ignoring HFE*001:01:02...
# Ignoring HFE*001:01:03...
# Ignoring HFE*002...
# Ignoring HFE*003...
# Ignoring HFE*004...
# Ignoring MICA*001:01...
# Ignoring MICA*001:02...
# Ignoring MICA*002:01:01...
# Ignoring MICA*002:01:02...
# Ignoring MICA*002:01:03...
# Ignoring MICA*002:01:04...
# Ignoring MICA*002:01:05...
# Ignoring MICA*002:01:06...
# Ignoring MICA*002:01:07...
# Ignoring MICA*002:01:08...
# Ignoring MICA*002:01:09...
# Ignoring MICA*002:01:10...
# Ignoring MICA*002:01:11...
# Ignoring MICA*002:01:12...
# Ignoring MICA*002:01:13Q...
# Ignoring MICA*002:01:14...
# Ignoring MICA*002:01:15...
# Ignoring MICA*002:01:16...
# Ignoring MICA*002:02...
# Ignoring MICA*002:03...
# Ignoring MICA*002:04...
# Ignoring MICA*002:05...
# Ignoring MICA*002:06...
# Ignoring MICA*002:07...
# Ignoring MICA*002:08...
# Ignoring MICA*002:09...
# Ignoring MICA*002:10...
# Ignoring MICA*002:11...
# Ignoring MICA*002:12...
# Ignoring MICA*004:01:01...
# Ignoring MICA*004:01:02...
# Ignoring MICA*004:01:03...
# Ignoring MICA*004:01:04...
# Ignoring MICA*004:01:05...
# Ignoring MICA*004:01:06...
# Ignoring MICA*004:01:07...
# Ignoring MICA*004:01:08...
# Ignoring MICA*004:01:09...
# Ignoring MICA*004:01:10...
# Ignoring MICA*004:01:11...
# Ignoring MICA*004:01:12...
# Ignoring MICA*004:01:13...
# Ignoring MICA*004:02...
# Ignoring MICA*004:03...
# Ignoring MICA*004:04...
# Ignoring MICA*005...
# Ignoring MICA*006...
# Ignoring MICA*007:01:01...
# Ignoring MICA*007:01:02...
# Ignoring MICA*007:01:03...
# Ignoring MICA*007:01:04...
# Ignoring MICA*007:01:05...
# Ignoring MICA*007:01:06...
# Ignoring MICA*007:01:07...
# Ignoring MICA*007:01:08...
# Ignoring MICA*007:01:09...
# Ignoring MICA*007:01:10...
# Ignoring MICA*007:03...
# Ignoring MICA*007:05...
# Ignoring MICA*007:06:01...
# Ignoring MICA*007:06:02...
# Ignoring MICA*007:07...
# Ignoring MICA*007:08...
# Ignoring MICA*007:09...
# Ignoring MICA*007:10...
# Ignoring MICA*008:01:01...
# Ignoring MICA*008:01:02...
# Ignoring MICA*008:01:03...
# Ignoring MICA*008:01:04...
# Ignoring MICA*008:01:05...
# Ignoring MICA*008:01:06...
# Ignoring MICA*008:01:07...
# Ignoring MICA*008:01:08...
# Ignoring MICA*008:01:09...
# Ignoring MICA*008:01:10...
# Ignoring MICA*008:01:11...
# Ignoring MICA*008:01:12...
# Ignoring MICA*008:01:13...
# Ignoring MICA*008:01:14...
# Ignoring MICA*008:01:15...
# Ignoring MICA*008:01:16...
# Ignoring MICA*008:01:17...
# Ignoring MICA*008:02...
# Ignoring MICA*008:03...
# Ignoring MICA*008:04:01...
# Ignoring MICA*008:04:02...
# Ignoring MICA*008:04:03...
# Ignoring MICA*008:04:04...
# Ignoring MICA*008:04:05...
# Ignoring MICA*008:04:06...
# Ignoring MICA*008:04:07...
# Ignoring MICA*008:05...
# Ignoring MICA*008:06...
# Ignoring MICA*008:08...
# Ignoring MICA*008:09...
# Ignoring MICA*008:10...
# Ignoring MICA*008:11...
# Ignoring MICA*008:12...
# Ignoring MICA*008:13...
# Ignoring MICA*008:14...
# Ignoring MICA*008:15...
# Ignoring MICA*008:16...
# Ignoring MICA*008:17...
# Ignoring MICA*008:18...
# Ignoring MICA*008:19...
# Ignoring MICA*008:20...
# Ignoring MICA*008:21...
# Ignoring MICA*008:22...
# Ignoring MICA*008:23:01...
# Ignoring MICA*008:23:02...
# Ignoring MICA*008:24...
# Ignoring MICA*008:25...
# Ignoring MICA*008:26...
# Ignoring MICA*008:27...
# Ignoring MICA*008:28...
# Ignoring MICA*008:29...
# Ignoring MICA*008:30...
# Ignoring MICA*008:31...
# Ignoring MICA*008:32...
# Ignoring MICA*008:33...
# Ignoring MICA*009:01:01...
# Ignoring MICA*009:01:02...
# Ignoring MICA*009:01:03...
# Ignoring MICA*009:01:04...
# Ignoring MICA*009:01:05...
# Ignoring MICA*009:01:06...
# Ignoring MICA*009:01:07...
# Ignoring MICA*009:01:08...
# Ignoring MICA*009:01:09...
# Ignoring MICA*009:01:10...
# Ignoring MICA*009:01:11...
# Ignoring MICA*009:02:01...
# Ignoring MICA*009:02:02...
# Ignoring MICA*009:02:03...
# Ignoring MICA*009:02:04...
# Ignoring MICA*009:02:05...
# Ignoring MICA*009:02:06...
# Ignoring MICA*009:03:01...
# Ignoring MICA*009:03:02...
# Ignoring MICA*009:04...
# Ignoring MICA*009:05...
# Ignoring MICA*009:06...
# Ignoring MICA*009:07...
# Ignoring MICA*009:08...
# Ignoring MICA*010:01:01...
# Ignoring MICA*010:01:02...
# Ignoring MICA*010:01:03...
# Ignoring MICA*010:01:04...
# Ignoring MICA*010:01:05...
# Ignoring MICA*010:01:06...
# Ignoring MICA*010:01:07...
# Ignoring MICA*010:01:08...
# Ignoring MICA*010:01:09...
# Ignoring MICA*010:02:01...
# Ignoring MICA*010:02:02...
# Ignoring MICA*010:03...
# Ignoring MICA*010:04...
# Ignoring MICA*010:05...
# Ignoring MICA*010:06...
# Ignoring MICA*010:07...
# Ignoring MICA*010:08...
# Ignoring MICA*010:09...
# Ignoring MICA*010:10...
# Ignoring MICA*010:11...
# Ignoring MICA*011:01:01...
# Ignoring MICA*011:01:02...
# Ignoring MICA*011:01:03...
# Ignoring MICA*011:01:04Q...
# Ignoring MICA*011:01:05...
# Ignoring MICA*011:01:06...
# Ignoring MICA*011:01:07...
# Ignoring MICA*011:01:08...
# Ignoring MICA*012:01:01...
# Ignoring MICA*012:01:02...
# Ignoring MICA*012:01:03...
# Ignoring MICA*012:02...
# Ignoring MICA*012:03...
# Ignoring MICA*012:04...
# Ignoring MICA*012:05...
# Ignoring MICA*012:06...
# Ignoring MICA*012:07...
# Ignoring MICA*012:08...
# Ignoring MICA*013...
# Ignoring MICA*014...
# Ignoring MICA*015:01...
# Ignoring MICA*015:02...
# Ignoring MICA*016:01:01...
# Ignoring MICA*016:01:02...
# Ignoring MICA*016:01:03...
# Ignoring MICA*016:02...
# Ignoring MICA*016:03...
# Ignoring MICA*017:01...
# Ignoring MICA*017:02...
# Ignoring MICA*017:03...
# Ignoring MICA*017:04...
# Ignoring MICA*018:01:01...
# Ignoring MICA*018:01:02...
# Ignoring MICA*018:01:03...
# Ignoring MICA*018:01:04...
# Ignoring MICA*018:01:05...
# Ignoring MICA*018:01:06...
# Ignoring MICA*018:01:07...
# Ignoring MICA*018:01:08...
# Ignoring MICA*018:01:09...
# Ignoring MICA*018:01:10...
# Ignoring MICA*018:01:11...
# Ignoring MICA*018:01:12...
# Ignoring MICA*018:02...
# Ignoring MICA*018:03...
# Ignoring MICA*019:01:01...
# Ignoring MICA*019:01:02...
# Ignoring MICA*019:01:03...
# Ignoring MICA*019:01:04...
# Ignoring MICA*019:02...
# Ignoring MICA*019:03...
# Ignoring MICA*020...
# Ignoring MICA*022:01:01...
# Ignoring MICA*022:01:02...
# Ignoring MICA*023...
# Ignoring MICA*024...
# Ignoring MICA*025...
# Ignoring MICA*026...
# Ignoring MICA*027:01:01...
# Ignoring MICA*027:01:02...
# Ignoring MICA*027:01:03...
# Ignoring MICA*027:02...
# Ignoring MICA*028...
# Ignoring MICA*029:01:01...
# Ignoring MICA*029:01:02...
# Ignoring MICA*029:02...
# Ignoring MICA*029:03...
# Ignoring MICA*030...
# Ignoring MICA*031...
# Ignoring MICA*032...
# Ignoring MICA*033...
# Ignoring MICA*034...
# Ignoring MICA*035...
# Ignoring MICA*036...
# Ignoring MICA*037...
# Ignoring MICA*038...
# Ignoring MICA*039...
# Ignoring MICA*040...
# Ignoring MICA*041...
# Ignoring MICA*042...
# Ignoring MICA*043...
# Ignoring MICA*044...
# Ignoring MICA*045:01:01...
# Ignoring MICA*045:01:02...
# Ignoring MICA*045:01:03...
# Ignoring MICA*046...
# Ignoring MICA*047...
# Ignoring MICA*048...
# Ignoring MICA*049:01:01...
# Ignoring MICA*049:01:02...
# Ignoring MICA*049:02...
# Ignoring MICA*050...
# Ignoring MICA*051...
# Ignoring MICA*052...
# Ignoring MICA*053:01:01...
# Ignoring MICA*053:01:02...
# Ignoring MICA*053:01:03...
# Ignoring MICA*053:01:04...
# Ignoring MICA*053:01:05...
# Ignoring MICA*054...
# Ignoring MICA*055...
# Ignoring MICA*056...
# Ignoring MICA*057:01:01...
# Ignoring MICA*057:01:02...
# Ignoring MICA*057:01:03...
# Ignoring MICA*057:01:04...
# Ignoring MICA*058...
# Ignoring MICA*059...
# Ignoring MICA*060...
# Ignoring MICA*061...
# Ignoring MICA*062:01:01...
# Ignoring MICA*062:01:02...
# Ignoring MICA*065...
# Ignoring MICA*066...
# Ignoring MICA*067...
# Ignoring MICA*068:01:01...
# Ignoring MICA*068:01:02...
# Ignoring MICA*068:02...
# Ignoring MICA*069...
# Ignoring MICA*070...
# Ignoring MICA*072:01:01...
# Ignoring MICA*072:01:02...
# Ignoring MICA*072:01:03...
# Ignoring MICA*073...
# Ignoring MICA*074...
# Ignoring MICA*075...
# Ignoring MICA*076...
# Ignoring MICA*077...
# Ignoring MICA*078...
# Ignoring MICA*079...
# Ignoring MICA*080...
# Ignoring MICA*081...
# Ignoring MICA*082...
# Ignoring MICA*083...
# Ignoring MICA*084...
# Ignoring MICA*085...
# Ignoring MICA*086...
# Ignoring MICA*087...
# Ignoring MICA*089...
# Ignoring MICA*090...
# Ignoring MICA*091...
# Ignoring MICA*092...
# Ignoring MICA*093...
# Ignoring MICA*094...
# Ignoring MICA*095...
# Ignoring MICA*097...
# Ignoring MICA*098:01...
# Ignoring MICA*098:02...
# Ignoring MICA*099:01:01...
# Ignoring MICA*099:01:02...
# Ignoring MICA*100...
# Ignoring MICA*101...
# Ignoring MICA*102...
# Ignoring MICA*103...
# Ignoring MICA*104...
# Ignoring MICA*105Q...
# Ignoring MICA*106...
# Ignoring MICA*108...
# Ignoring MICA*109...
# Ignoring MICA*110...
# Ignoring MICA*111:01...
# Ignoring MICA*111:02...
# Ignoring MICA*112:01:01...
# Ignoring MICA*112:01:02...
# Ignoring MICA*112:01:03...
# Ignoring MICA*112:01:04...
# Ignoring MICA*112:01:05...
# Ignoring MICA*113...
# Ignoring MICA*114...
# Ignoring MICA*115...
# Ignoring MICA*116...
# Ignoring MICA*117...
# Ignoring MICA*118...
# Ignoring MICA*119:01:01...
# Ignoring MICA*119:01:02...
# Ignoring MICA*120...
# Ignoring MICA*121...
# Ignoring MICA*122...
# Ignoring MICA*123...
# Ignoring MICA*124:01:01...
# Ignoring MICA*124:01:02...
# Ignoring MICA*125...
# Ignoring MICA*126...
# Ignoring MICA*127...
# Ignoring MICA*128...
# Ignoring MICA*129...
# Ignoring MICA*130:01...
# Ignoring MICA*130:02...
# Ignoring MICA*131...
# Ignoring MICA*132...
# Ignoring MICA*133...
# Ignoring MICA*134...
# Ignoring MICA*135...
# Ignoring MICA*136...
# Ignoring MICA*137:01:01...
# Ignoring MICA*137:01:02...
# Ignoring MICA*138...
# Ignoring MICA*139...
# Ignoring MICA*140...
# Ignoring MICA*141...
# Ignoring MICA*142:01:01...
# Ignoring MICA*142:01:02...
# Ignoring MICA*143...
# Ignoring MICA*144...
# Ignoring MICA*145...
# Ignoring MICA*146...
# Ignoring MICA*147...
# Ignoring MICA*148...
# Ignoring MICA*149...
# Ignoring MICA*150...
# Ignoring MICA*151:01:01...
# Ignoring MICA*151:01:02...
# Ignoring MICA*151:01:03...
# Ignoring MICA*152...
# Ignoring MICA*153...
# Ignoring MICA*154...
# Ignoring MICA*155...
# Ignoring MICA*156...
# Ignoring MICA*157...
# Ignoring MICA*158...
# Ignoring MICA*159...
# Ignoring MICA*160...
# Ignoring MICA*161...
# Ignoring MICA*162...
# Ignoring MICA*163...
# Ignoring MICA*164...
# Ignoring MICA*165...
# Ignoring MICA*166:01:01...
# Ignoring MICA*166:01:02...
# Ignoring MICA*166:01:03...
# Ignoring MICA*167...
# Ignoring MICA*168:01:01...
# Ignoring MICA*168:01:02...
# Ignoring MICA*169...
# Ignoring MICA*170...
# Ignoring MICA*171Q...
# Ignoring MICA*172...
# Ignoring MICA*173...
# Ignoring MICA*174...
# Ignoring MICA*175...
# Ignoring MICA*176...
# Ignoring MICA*177...
# Ignoring MICA*178...
# Ignoring MICA*179...
# Ignoring MICA*180...
# Ignoring MICA*181...
# Ignoring MICA*182...
# Ignoring MICA*183...
# Ignoring MICA*184...
# Ignoring MICA*185...
# Ignoring MICA*186...
# Ignoring MICA*187...
# Ignoring MICA*188...
# Ignoring MICA*189...
# Ignoring MICA*190...
# Ignoring MICA*191...
# Ignoring MICA*192...
# Ignoring MICA*193...
# Ignoring MICA*194...
# Ignoring MICA*196...
# Ignoring MICA*197...
# Ignoring MICA*198...
# Ignoring MICA*199...
# Ignoring MICA*200...
# Ignoring MICA*201...
# Ignoring MICA*202...
# Ignoring MICA*203...
# Ignoring MICA*204...
# Ignoring MICA*205...
# Ignoring MICA*206...
# Ignoring MICA*207...
# Ignoring MICA*208:01:01...
# Ignoring MICA*208:01:02...
# Ignoring MICA*208:01:03...
# Ignoring MICA*209...
# Ignoring MICA*210...
# Ignoring MICA*211...
# Ignoring MICA*212...
# Ignoring MICA*213...
# Ignoring MICA*214...
# Ignoring MICA*215...
# Ignoring MICA*216:01:01...
# Ignoring MICA*216:01:02...
# Ignoring MICA*217...
# Ignoring MICA*218...
# Ignoring MICA*219...
# Ignoring MICA*220...
# Ignoring MICA*221...
# Ignoring MICA*223...
# Ignoring MICA*224...
# Ignoring MICA*225...
# Ignoring MICA*226...
# Ignoring MICA*227...
# Ignoring MICA*228...
# Ignoring MICA*229...
# Ignoring MICA*230...
# Ignoring MICA*231...
# Ignoring MICA*232...
# Ignoring MICA*233...
# Ignoring MICA*234...
# Ignoring MICA*235...
# Ignoring MICA*236:01:01...
# Ignoring MICA*236:01:02...
# Ignoring MICA*237...
# Ignoring MICA*238...
# Ignoring MICA*239...
# Ignoring MICA*240...
# Ignoring MICA*241...
# Ignoring MICA*242...
# Ignoring MICA*243...
# Ignoring MICA*244...
# Ignoring MICA*245...
# Ignoring MICA*246...
# Ignoring MICA*247...
# Ignoring MICA*248...
# Ignoring MICA*249...
# Ignoring MICA*250...
# Ignoring MICA*251...
# Ignoring MICA*252...
# Ignoring MICA*253...
# Ignoring MICA*254...
# Ignoring MICA*255...
# Ignoring MICA*256...
# Ignoring MICA*257...
# Ignoring MICA*258...
# Ignoring MICA*259...
# Ignoring MICA*260...
# Ignoring MICA*261...
# Ignoring MICA*262...
# Ignoring MICA*263...
# Ignoring MICA*264...
# Ignoring MICA*265...
# Ignoring MICA*266...
# Ignoring MICA*267...
# Ignoring MICA*268...
# Ignoring MICA*269...
# Ignoring MICA*270...
# Ignoring MICA*271...
# Ignoring MICA*272...
# Ignoring MICA*273...
# Ignoring MICA*274...
# Ignoring MICA*275...
# Ignoring MICA*276...
# Ignoring MICA*277...
# Ignoring MICA*278...
# Ignoring MICA*279...
# Ignoring MICA*280...
# Ignoring MICA*281...
# Ignoring MICA*282...
# Ignoring MICA*283...
# Ignoring MICA*284...
# Ignoring MICA*285...
# Ignoring MICA*287...
# Ignoring MICA*288...
# Ignoring MICA*289...
# Ignoring MICA*290...
# Ignoring MICA*291...
# Ignoring MICB*001...
# Ignoring MICB*002:01:01...
# Ignoring MICB*002:01:02...
# Ignoring MICB*002:01:03...
# Ignoring MICB*002:01:04...
# Ignoring MICB*002:01:05...
# Ignoring MICB*002:01:06...
# Ignoring MICB*002:01:07...
# Ignoring MICB*002:01:08...
# Ignoring MICB*002:01:09...
# Ignoring MICB*002:01:10...
# Ignoring MICB*002:01:11...
# Ignoring MICB*002:01:12...
# Ignoring MICB*002:01:13...
# Ignoring MICB*002:01:14...
# Ignoring MICB*002:01:15...
# Ignoring MICB*002:01:16...
# Ignoring MICB*002:01:17...
# Ignoring MICB*002:01:18...
# Ignoring MICB*002:01:19...
# Ignoring MICB*002:01:20...
# Ignoring MICB*002:01:21...
# Ignoring MICB*002:01:22...
# Ignoring MICB*002:01:23...
# Ignoring MICB*002:01:24...
# Ignoring MICB*002:01:25...
# Ignoring MICB*002:01:26...
# Ignoring MICB*002:01:27...
# Ignoring MICB*002:01:28...
# Ignoring MICB*002:02:01...
# Ignoring MICB*002:02:02...
# Ignoring MICB*002:03...
# Ignoring MICB*002:04...
# Ignoring MICB*002:05...
# Ignoring MICB*003:01:01...
# Ignoring MICB*003:01:02...
# Ignoring MICB*003:01:03...
# Ignoring MICB*003:01:04...
# Ignoring MICB*003:01:05...
# Ignoring MICB*003:01:06...
# Ignoring MICB*003:01:07...
# Ignoring MICB*003:01:08...
# Ignoring MICB*003:01:09...
# Ignoring MICB*003:01:10...
# Ignoring MICB*003:01:11...
# Ignoring MICB*003:01:12...
# Ignoring MICB*004:01:01...
# Ignoring MICB*004:01:02...
# Ignoring MICB*004:01:03...
# Ignoring MICB*004:01:04...
# Ignoring MICB*004:01:05...
# Ignoring MICB*004:01:06...
# Ignoring MICB*004:01:07...
# Ignoring MICB*004:01:08...
# Ignoring MICB*004:01:09...
# Ignoring MICB*004:01:10...
# Ignoring MICB*004:01:11...
# Ignoring MICB*004:01:12...
# Ignoring MICB*004:01:13...
# Ignoring MICB*004:01:14...
# Ignoring MICB*004:01:15...
# Ignoring MICB*004:01:16...
# Ignoring MICB*004:01:17...
# Ignoring MICB*004:01:18...
# Ignoring MICB*004:01:19...
# Ignoring MICB*004:01:20...
# Ignoring MICB*004:01:21...
# Ignoring MICB*004:01:22...
# Ignoring MICB*004:01:23...
# Ignoring MICB*004:01:24...
# Ignoring MICB*004:01:25...
# Ignoring MICB*004:01:26...
# Ignoring MICB*004:01:27...
# Ignoring MICB*004:02...
# Ignoring MICB*005:01:01...
# Ignoring MICB*005:01:02...
# Ignoring MICB*005:01:03...
# Ignoring MICB*005:02:01...
# Ignoring MICB*005:02:02...
# Ignoring MICB*005:02:03...
# Ignoring MICB*005:02:04...
# Ignoring MICB*005:02:05...
# Ignoring MICB*005:02:06...
# Ignoring MICB*005:02:07...
# Ignoring MICB*005:02:08...
# Ignoring MICB*005:02:09...
# Ignoring MICB*005:02:10...
# Ignoring MICB*005:02:11...
# Ignoring MICB*005:02:12...
# Ignoring MICB*005:02:13...
# Ignoring MICB*005:02:14...
# Ignoring MICB*005:02:15...
# Ignoring MICB*005:02:16...
# Ignoring MICB*005:02:17...
# Ignoring MICB*005:02:18...
# Ignoring MICB*005:02:19...
# Ignoring MICB*005:02:20...
# Ignoring MICB*005:02:21...
# Ignoring MICB*005:02:22...
# Ignoring MICB*005:02:23...
# Ignoring MICB*005:02:24...
# Ignoring MICB*005:02:25...
# Ignoring MICB*005:02:26...
# Ignoring MICB*005:02:27...
# Ignoring MICB*005:02:28...
# Ignoring MICB*005:02:29...
# Ignoring MICB*005:02:30...
# Ignoring MICB*005:02:31...
# Ignoring MICB*005:02:32...
# Ignoring MICB*005:02:33...
# Ignoring MICB*005:02:34...
# Ignoring MICB*005:03:01...
# Ignoring MICB*005:03:02...
# Ignoring MICB*005:03:03...
# Ignoring MICB*005:03:04...
# Ignoring MICB*005:03:05...
# Ignoring MICB*005:04...
# Ignoring MICB*005:05...
# Ignoring MICB*005:06:01...
# Ignoring MICB*005:06:02...
# Ignoring MICB*005:06:03...
# Ignoring MICB*005:07:01...
# Ignoring MICB*005:07:02...
# Ignoring MICB*005:08...
# Ignoring MICB*005:09...
# Ignoring MICB*005:10...
# Ignoring MICB*005:11...
# Ignoring MICB*005:12...
# Ignoring MICB*006...
# Ignoring MICB*007...
# Ignoring MICB*008:01:01...
# Ignoring MICB*008:01:02...
# Ignoring MICB*008:01:03...
# Ignoring MICB*008:01:04...
# Ignoring MICB*008:01:05...
# Ignoring MICB*008:01:06...
# Ignoring MICB*008:01:07...
# Ignoring MICB*008:01:08...
# Ignoring MICB*008:01:09...
# Ignoring MICB*008:01:10...
# Ignoring MICB*008:01:11...
# Ignoring MICB*010...
# Ignoring MICB*011...
# Ignoring MICB*012...
# Ignoring MICB*013:01:01...
# Ignoring MICB*013:01:02...
# Ignoring MICB*013:01:03...
# Ignoring MICB*013:01:04...
# Ignoring MICB*013:01:05...
# Ignoring MICB*013:01:06...
# Ignoring MICB*014:01:01...
# Ignoring MICB*014:01:02...
# Ignoring MICB*014:01:03...
# Ignoring MICB*014:01:04...
# Ignoring MICB*014:01:05...
# Ignoring MICB*014:01:06...
# Ignoring MICB*014:01:07...
# Ignoring MICB*014:01:08...
# Ignoring MICB*015...
# Ignoring MICB*016...
# Ignoring MICB*018:01:01...
# Ignoring MICB*018:01:02...
# Ignoring MICB*018:01:03...
# Ignoring MICB*019:01:01...
# Ignoring MICB*019:01:02...
# Ignoring MICB*019:01:03...
# Ignoring MICB*019:01:04...
# Ignoring MICB*019:01:05...
# Ignoring MICB*019:01:06...
# Ignoring MICB*019:01:07...
# Ignoring MICB*019:01:08...
# Ignoring MICB*020:01:01...
# Ignoring MICB*020:01:02...
# Ignoring MICB*020:01:03...
# Ignoring MICB*022...
# Ignoring MICB*023...
# Ignoring MICB*024:01:01...
# Ignoring MICB*024:01:02...
# Ignoring MICB*024:01:03...
# Ignoring MICB*024:01:04...
# Ignoring MICB*024:01:05...
# Ignoring MICB*024:01:06...
# Ignoring MICB*025:01:01...
# Ignoring MICB*025:01:02...
# Ignoring MICB*025:01:03...
# Ignoring MICB*025:01:04...
# Ignoring MICB*025:01:05...
# Ignoring MICB*026...
# Ignoring MICB*027...
# Ignoring MICB*028...
# Ignoring MICB*029...
# Ignoring MICB*030...
# Ignoring MICB*031:01:01...
# Ignoring MICB*031:01:02...
# Ignoring MICB*031:01:03...
# Ignoring MICB*031:01:04...
# Ignoring MICB*031:01:05...
# Ignoring MICB*031:01:06...
# Ignoring MICB*032...
# Ignoring MICB*033...
# Ignoring MICB*034...
# Ignoring MICB*035...
# Ignoring MICB*036...
# Ignoring MICB*037...
# Ignoring MICB*038...
# Ignoring MICB*039...
# Ignoring MICB*040...
# Ignoring MICB*042...
# Ignoring MICB*044...
# Ignoring MICB*046...
# Ignoring MICB*047...
# Ignoring MICB*048...
# Ignoring TAP1*01:01:01:01...
# Ignoring TAP1*01:01:01:02...
# Ignoring TAP1*01:01:01:03...
# Ignoring TAP1*01:01:01:04...
# Ignoring TAP1*01:01:01:05...
# Ignoring TAP1*02:01:01...
# Ignoring TAP1*02:01:02...
# Ignoring TAP1*03:01...
# Ignoring TAP1*04:01...
# Ignoring TAP1*05:01...
# Ignoring TAP1*06:01...
# Ignoring TAP2*01:01:01...
# Ignoring TAP2*01:01:02...
# Ignoring TAP2*01:01:03:01...
# Ignoring TAP2*01:01:03:02...
# Ignoring TAP2*01:01:03:03...
# Ignoring TAP2*01:02...
# Ignoring TAP2*01:03...
# Ignoring TAP2*01:04...
# Ignoring TAP2*02:01:01...
# Ignoring TAP2*02:01:02:01...
# Ignoring TAP2*02:01:02:02...
# Ignoring TAP2*02:01:02:03...

# %%
combined_decomposed = list(
    dict.fromkeys(
        sorted(g_groups_decomposed + p_groups_decomposed + proteins_decomposed)
    )
)

# %%
def make_hla_tree(current_root: dict, token_lists: list) -> None:
    first_tokens = list(
        dict.fromkeys(
            sorted([token_list[0] for token_list in token_lists])
        )
    )

    for token in first_tokens:
        current_root[token] = {}

        new_token_lists = [
            token_list[1:] for token_list in token_lists \
            if token_list[0] == token and \
            len(token_list) > 1
        ]

        make_hla_tree(current_root[token], new_token_lists)

# %%
hla_tree = {}

make_hla_tree(hla_tree, combined_decomposed)

# %%
with open('src/resources/human_mhc_alleles_exhaustive.json', 'w') as f:
    json.dump(hla_tree, f, indent=4)
